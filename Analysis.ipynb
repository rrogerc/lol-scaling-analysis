# %%
import pandas as pd

pd.set_option("display.precision", 3)

# %%
m_plus = pd.read_json("./master_plus.json").T
m_plus = m_plus.sort_values(by=6, ascending=False)
m_plus.head(10)

# %%
d_plus = pd.read_json("./diamond_plus.json").T
d_plus = d_plus.sort_values(by=6, ascending=False)
d_plus.head(10)
# Out:
#                   0      1      2      3      4      5      6
# Heimerdinger  0.379  0.555  0.569  0.557  0.510  0.561  0.570
# Nilah         0.549  0.538  0.511  0.531  0.558  0.577  0.569
# Veigar        0.455  0.520  0.560  0.542  0.541  0.555  0.567
# Vayne         0.520  0.526  0.533  0.552  0.559  0.560  0.565
# Twitch        0.546  0.572  0.532  0.538  0.546  0.556  0.564
# Aphelios      0.510  0.450  0.479  0.500  0.520  0.538  0.559
# Tahm Kench    0.673  0.625  0.585  0.560  0.573  0.565  0.556
# Jhin          0.569  0.523  0.525  0.533  0.538  0.542  0.552
# Miss Fortune  0.507  0.495  0.508  0.534  0.547  0.568  0.548
# Ashe          0.539  0.531  0.550  0.547  0.537  0.530  0.547
